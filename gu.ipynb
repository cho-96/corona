# %%
import geopandas as gpd
b = gpd.read_file('gu\gu.shp')
gu = b[['SIG_CD','SIG_ENG_NM']]
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
import datetime
import os
import zipfile
curDir = os.getcwd()
zf = zipfile.ZipFile(curDir + '\\LOCAL_PEOPLE_202003.zip')
text_files = zf.infolist()
list_ = []
for text_file in text_files:
    print(text_file.filename)
    df7 = pd.read_csv(zf.open(text_file.filename), encoding='cp949', usecols=[0,1,2,3,4])
    list_.append(df7)
df7 = pd.concat(list_)
df7 = df7[['?"기준일ID"','시간대구분','행정동코드','집계구코드','총생활인구수']]
df7['gu'] = [str(x)[:5] for x in df7['행정동코드']]
df7 = df7.merge(gu, how='left', left_on='gu', right_on='SIG_CD')
df7 = df7[['?"기준일ID"','시간대구분','행정동코드','집계구코드','총생활인구수','SIG_ENG_NM']]
df7 = df7.groupby(['?"기준일ID"','시간대구분','SIG_ENG_NM'])['총생활인구수'].agg('sum')
df7 = df7.reset_index()
df7['?"기준일ID"'] = df7['?"기준일ID"'].astype(str)
df7['date'] = [x[6:] for x in df7['?"기준일ID"']]
df7.columns = ['wholedate','hour','gu','floating population','date']
# Out:
# LOCAL_PEOPLE_20200309.csv
# LOCAL_PEOPLE_20200301.csv
# LOCAL_PEOPLE_20200316.csv
# LOCAL_PEOPLE_20200311.csv
# LOCAL_PEOPLE_20200306.csv
# LOCAL_PEOPLE_20200328.csv
# LOCAL_PEOPLE_20200329.csv
# LOCAL_PEOPLE_20200304.csv
# LOCAL_PEOPLE_20200315.csv
# LOCAL_PEOPLE_20200324.csv
# LOCAL_PEOPLE_20200307.csv
# LOCAL_PEOPLE_20200326.csv
# LOCAL_PEOPLE_20200318.csv
# LOCAL_PEOPLE_20200305.csv
# LOCAL_PEOPLE_20200312.csv
# LOCAL_PEOPLE_20200314.csv
# LOCAL_PEOPLE_20200321.csv
# LOCAL_PEOPLE_20200308.csv
# LOCAL_PEOPLE_20200327.csv
# LOCAL_PEOPLE_20200303.csv
# LOCAL_PEOPLE_20200331.csv
# LOCAL_PEOPLE_20200317.csv
# LOCAL_PEOPLE_20200323.csv
# LOCAL_PEOPLE_20200313.csv
# LOCAL_PEOPLE_20200330.csv
# LOCAL_PEOPLE_20200322.csv
# LOCAL_PEOPLE_20200319.csv
# LOCAL_PEOPLE_20200320.csv
# LOCAL_PEOPLE_20200302.csv
# LOCAL_PEOPLE_20200325.csv
# LOCAL_PEOPLE_20200310.csv

# %%
fig, ax = plt.subplots(figsize=(14, 10))
sns.lineplot(data=df7, x='date', y='floating population',hue = 'gu', ax=ax)
plt.title('202003 floating population per administrative region')
plt.axvline(x = '09', color = 'b', ls = '--', alpha = 0.6)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(14, 10))
sns.lineplot(data=df7, x='hour', y='floating population',hue = 'gu', ax=ax)
plt.title('202003 floating population per administrative region(hour)')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
import geopandas as gpd
b = gpd.read_file('gu\gu.shp')
gu = b[['SIG_CD','SIG_ENG_NM']]
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
import datetime
import os
import zipfile
curDir = os.getcwd()
directory = os.listdir(curDir + '\\202004')
list_ = []
for zipf in directory:
    zf = zipfile.ZipFile(curDir + '\\202004' + '\\' + zipf)
    text_files = zf.infolist()
    for text_file in text_files:
        print(text_file.filename)
        df9 = pd.read_csv(zf.open(text_file.filename), encoding='cp949', usecols=[0,1,2,3,4])
        list_.append(df9)
df9 = pd.concat(list_)
df9 = df9[['?"기준일ID"','시간대구분','행정동코드','집계구코드','총생활인구수']]
df9['gu'] = [str(x)[:5] for x in df9['행정동코드']]
df9 = df9.merge(gu, how='left', left_on='gu', right_on='SIG_CD')
df9 = df9[['?"기준일ID"','시간대구분','행정동코드','집계구코드','총생활인구수','SIG_ENG_NM']]
df9 = df9.groupby(['?"기준일ID"','시간대구분','SIG_ENG_NM'])['총생활인구수'].agg('sum')
df9 = df9.reset_index()
df9['?"기준일ID"'] = df9['?"기준일ID"'].astype(str)
df9['date'] = [x[6:] for x in df9['?"기준일ID"']]
df9.columns = ['wholedate','hour','gu','floating population','date']
# Out:
# LOCAL_PEOPLE_20200401.csv
# LOCAL_PEOPLE_20200402.csv
# LOCAL_PEOPLE_20200403.csv
# LOCAL_PEOPLE_20200404.csv
# LOCAL_PEOPLE_20200405.csv
# LOCAL_PEOPLE_20200406.csv
# LOCAL_PEOPLE_20200407.csv
# LOCAL_PEOPLE_20200408.csv
# LOCAL_PEOPLE_20200409.csv
# LOCAL_PEOPLE_20200410.csv
# LOCAL_PEOPLE_20200411.csv
# LOCAL_PEOPLE_20200412.csv
# LOCAL_PEOPLE_20200413.csv
# LOCAL_PEOPLE_20200414.csv
# LOCAL_PEOPLE_20200415.csv
# LOCAL_PEOPLE_20200416.csv
# LOCAL_PEOPLE_20200417.csv
# LOCAL_PEOPLE_20200418.csv

# %%
fig, ax = plt.subplots(figsize=(14, 10))
sns.lineplot(data=df9, x='date', y='floating population',hue = 'gu', ax=ax)
plt.title('202004 floating population per administrative region')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(14, 10))
sns.lineplot(data=df9, x='hour', y='floating population',hue = 'gu', ax=ax)
plt.title('202004 floating population per administrative region(hour)')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

plt.show()

# %%
curDir = os.getcwd()
zf = zipfile.ZipFile(curDir + '\\LOCAL_PEOPLE_202002.zip')
text_files = zf.infolist()
list_ = []
for text_file in text_files:
    date = text_file.filename
    date = date[19:21]
    if int(date) < 17:
        print(text_file.filename)
        df10 = pd.read_csv(zf.open(text_file.filename), usecols=[0,1,2,3,4])
        list_.append(df10)
    else:
        print(text_file.filename)
        df10 = pd.read_csv(zf.open(text_file.filename), encoding='cp949', usecols=[0,1,2,3,4])
        list_.append(df10)
# Out:
# LOCAL_PEOPLE_20200210.csv
# LOCAL_PEOPLE_20200217.csv
# LOCAL_PEOPLE_20200206.csv
# LOCAL_PEOPLE_20200228.csv
# LOCAL_PEOPLE_20200218.csv
# LOCAL_PEOPLE_20200222.csv
# LOCAL_PEOPLE_20200205.csv
# LOCAL_PEOPLE_20200226.csv
# LOCAL_PEOPLE_20200201.csv
# LOCAL_PEOPLE_20200202.csv
# LOCAL_PEOPLE_20200203.csv
# LOCAL_PEOPLE_20200216.csv
# LOCAL_PEOPLE_20200213.csv
# LOCAL_PEOPLE_20200214.csv
# LOCAL_PEOPLE_20200211.csv
# LOCAL_PEOPLE_20200221.csv
# LOCAL_PEOPLE_20200219.csv
# LOCAL_PEOPLE_20200204.csv
# LOCAL_PEOPLE_20200209.csv
# LOCAL_PEOPLE_20200224.csv
# LOCAL_PEOPLE_20200220.csv
# LOCAL_PEOPLE_20200215.csv
# LOCAL_PEOPLE_20200212.csv
# LOCAL_PEOPLE_20200208.csv
# LOCAL_PEOPLE_20200207.csv
# LOCAL_PEOPLE_20200225.csv
# LOCAL_PEOPLE_20200223.csv
# LOCAL_PEOPLE_20200227.csv
# LOCAL_PEOPLE_20200229.csv
# C:\Users\Main\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# ...

# %%
for listi in list_:
    listi.columns = ['기준일ID','시간대구분','행정동코드','집계구코드','총생활인구수']

# %%
list_
# Out:
# [           기준일ID  시간대구분     행정동코드          집계구코드  총생활인구수
#  0       20200210      0  11110515  1101072010001   560.0
#  1       20200210      0  11110515  1101072010002   690.0
#  2       20200210      0  11110515  1101072010003    62.0
#  3       20200210      0  11110515  1101072010004   309.0
#  4       20200210      0  11110515  1101072010005   171.0
#  ...          ...    ...       ...            ...     ...
#  459645  20200210     23  11740700  1125071022201   995.0
#  459646  20200210     23  11740700  1125071022202   250.0
#  459647  20200210     23  11740700  1125071022501  1209.0
#  459648  20200210     23  11740700  1125071022701   223.0
#  459649  20200210     23  11740700  1125071023701   703.0
#
#  [459650 rows x 5 columns],
#             기준일ID  시간대구분     행정동코드          집계구코드  총생활인구수
#  0       20200217      0  11110515  1101072010001     574
#  1       20200217      0  11110515  1101072010002     660
#  2       20200217      0  11110515  1101072010003      87
# ...

# %%
df10 = pd.concat(list_)
df10 = df10[['기준일ID','시간대구분','행정동코드','집계구코드','총생활인구수']]
df10['gu'] = [str(x)[:5] for x in df10['행정동코드']]
df10 = df10.merge(gu, how='left', left_on='gu', right_on='SIG_CD')
df10 = df10[['기준일ID','시간대구분','행정동코드','집계구코드','총생활인구수','SIG_ENG_NM']]
df10 = df10.groupby(['기준일ID','시간대구분','SIG_ENG_NM'])['총생활인구수'].agg('sum')
df10 = df10.reset_index()
df10['기준일ID'] = df10['기준일ID'].astype(str)
df10['date'] = [x[6:] for x in df10['기준일ID']]
df10.columns = ['wholedate','hour','gu','floating population','date']

# %%
fig, ax = plt.subplots(figsize=(14, 10))
sns.lineplot(data=df10, x='date', y='floating population',hue = 'gu', ax=ax)
plt.title('202002 floating population per administrative region')
plt.axvline(x = '13', color = 'b', ls = '--', alpha = 0.6) 
plt.axvline(x = '17', color = 'r', ls = '--', alpha = 0.6) 
plt.axvline(x = '23', color = 'g', ls = '--', alpha = 0.6) 
plt.show()

# %%
fig, ax = plt.subplots(figsize=(14, 10))
sns.lineplot(data=df10, x='hour', y='floating population',hue = 'gu', ax=ax)
plt.title('202002 floating population per administrative region(hour)')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(14, 10))
sns.lineplot(data=df10, x='date', y='floating population',hue = 'gu', ax=ax)
plt.title('202002 floating population per administrative region')
plt.show()
